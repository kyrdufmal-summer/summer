# %%
student = {
    "name": "민수",
    "score":85,
}

def show_result(stu):
    print(f"{stu['name']}의 점수는 {stu['score']}점입니다.")

# %%
class Student:
    pass
student1 = Student()
student2 = Student()

print(student1 is student2)

# %%
class Student:
    def __init__(self, name, score):
        self.name = name
        self.score = score

# %%
class Student:

    def __init__(self, name, score):
        self.name = name
        self.score = score
        

    def show_result(self):
        print(f"{self.name}: {self.score}점")

    def is_passed(self):
        return self.score >= 60

# %%
student1 = Student("홍길동", 45)
stdunet2 = Student("김여름", 30)
print(student1)
show_result = show_result()
print(show_result)

print(f"홍길동님의 점수는 {show_result.score}점 입니다.")
print("홍길동님은 이번 시험에서 아쉽지만 탈락(당당히 합격) 하셨습니다. ")
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 student1 = Student("홍길동", 45)
#       2 stdunet2 = Student("김여름", 30)
#       3 print(student1)
# ----> 4 show_result = show_result()
#       5 print(show_result)
#       6
#       7 print(f"홍길동님의 점수는 {show_result.score}점 입니다.")
#
# NameError: name 'show_result' is not defined
